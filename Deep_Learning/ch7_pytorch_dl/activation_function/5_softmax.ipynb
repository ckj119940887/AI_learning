# %%
import torch

# %%
x = torch.randn(3, 5)
# 哪一维是特征,特征按照行存放，dim=1
y = torch.softmax(x, dim=1)
print(x)
print(y)
# Out:
# tensor([[-0.6049,  0.9987,  1.7280, -0.8132,  0.3502],
#         [ 0.2247,  0.5081, -0.7291,  0.3058,  0.8556],
#         [-0.1518, -0.4704, -0.3247,  0.4557,  0.3493]])
# tensor([[0.0508, 0.2525, 0.5235, 0.0412, 0.1320],
#         [0.1762, 0.2339, 0.0679, 0.1910, 0.3310],
#         [0.1652, 0.1201, 0.1389, 0.3032, 0.2726]])
