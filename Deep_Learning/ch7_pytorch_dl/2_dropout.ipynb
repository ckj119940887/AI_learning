# %%
import torch

# %%
x = torch.randint(low=1, high=10, size=(10,), dtype=torch.float)

print(x)
# Out:
# tensor([6., 7., 4., 2., 8., 4., 9., 1., 6., 2.])

# %%
dropout = torch.nn.Dropout(p=0.5)
print(dropout(x))
# Out:
# tensor([12., 14.,  8.,  4., 16.,  8., 18.,  0.,  0.,  4.])
