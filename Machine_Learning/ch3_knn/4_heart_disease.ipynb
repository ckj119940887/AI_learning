# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV #网格搜索，交叉验证
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer #列转换，特征转换
from sklearn.neighbors import KNeighborsClassifier
import joblib

# %%
# 1.加载数据
heart_disease_data = pd.read_csv("../data/heart_disease.csv")

# 数据清洗
heart_disease_data.dropna(inplace=True)

# 2.数据集划分
# 定义特征
# axis=1 表示按“列”删除
X = heart_disease_data.drop("是否患有心脏病", axis=1)
y = heart_disease_data["是否患有心脏病"]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3.特征工程
# 数值型
numerical_features = ["年龄", "静息血压", "胆固醇", "最大心率", "运动后的ST下降", "主血管数量"]

# 类别型
categorical_features = ["胸痛类型", "静息心电图结果", "峰值ST段的斜率", "地中海贫血"]

# 二元特征
binary_features = ["性别", "空腹血糖", "运动性心绞痛"]

# 创建列转换器
transformer = ColumnTransformer(
    # (名称，操作，特征列表)
    transformers= [
        ("num", StandardScaler(), numerical_features),
        # drop="first"是独热编码中的一个参数，它的核心目的是避免多重共线性
        ("cat", OneHotEncoder(drop="first"), categorical_features),
        ("bin", "passthrough", binary_features)
    ]
)

# 用 fit_transform：当你在一份数据上既要学习参数（fit）又要立刻做变换（transform），通常发生在训练集上。
# 用 transform：当变换器的参数已经从训练集学好了，你要把同样的变换应用到验证集/测试集/新数据上，保证不泄漏信息。
x_train = transformer.fit_transform(x_train)
x_test = transformer.transform(x_test)

# 4.创建模型训练
# knn = KNeighborsClassifier(n_neighbors=3)
knn = KNeighborsClassifier()
# cv -- cross validation
knn = GridSearchCV(estimator=knn, param_grid={"n_neighbors":np.arange(1, 11), "weights":["uniform", "distance"]}, cv=10)

knn.fit(x_train, y_train)
print(pd.DataFrame(knn.cv_results_))
print(knn.best_estimator_)
print(knn.best_score_)

# 5.测试，模型评估
#print(knn.score(x_test, y_test))

# 6.模型保存
#joblib.dump(knn, "../data/knn.joblib")

# 7.模型加载
#knn_load = joblib.load("../data/knn.joblib")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000350      0.000125         0.004434        0.010519
# 1        0.000263      0.000022         0.000908        0.000117
# 2        0.000239      0.000012         0.000659        0.000035
# 3        0.000271      0.000017         0.000890        0.000040
# 4        0.000249      0.000013         0.000777        0.000137
# 5        0.000276      0.000010         0.001002        0.000136
# 6        0.000271      0.000035         0.000789        0.000081
# 7        0.000294      0.000027         0.001158        0.000489
# 8        0.000284      0.000054         0.000997        0.000516
# 9        0.000292      0.000013         0.001045        0.000110
# 10       0.000259      0.000020         0.000898        0.000319
# 11       0.000281      0.000012         0.001081        0.000179
# 12       0.000259      0.000016         0.000874        0.000314
# 13       0.000276      0.000013         0.000998        0.000094
# 14       0.000244      0.000015         0.000867        0.000378
# 15       0.000293      0.000063         0.002235        0.003411
# 16       0.000274      0.000046         0.000905        0.000412
# 17       0.000278      0.000028         0.001051        0.000211
# 18       0.000249      0.000015         0.000787        0.000103
# 19       0.000283      0.000016         0.001202        0.000479
#
#     param_n_neighbors param_weights  \
# 0                   1       uniform
# 1                   1      distance
# 2                   2       uniform
# 3                   2      distance
# 4                   3       uniform
# 5                   3      distance
# 6                   4       uniform
# 7                   4      distance
# 8                   5       uniform
# 9                   5      distance
# 10                  6       uniform
# 11                  6      distance
# 12                  7       uniform
# 13                  7      distance
# 14                  8       uniform
# 15                  8      distance
# 16                  9       uniform
# 17                  9      distance
# 18                 10       uniform
# 19                 10      distance
#
#                                         params  split0_test_score  \
# 0     {'n_neighbors': 1, 'weights': 'uniform'}           0.986111
# 1    {'n_neighbors': 1, 'weights': 'distance'}           0.986111
# 2     {'n_neighbors': 2, 'weights': 'uniform'}           0.944444
# 3    {'n_neighbors': 2, 'weights': 'distance'}           0.986111
# 4     {'n_neighbors': 3, 'weights': 'uniform'}           0.930556
# 5    {'n_neighbors': 3, 'weights': 'distance'}           0.986111
# 6     {'n_neighbors': 4, 'weights': 'uniform'}           0.902778
# 7    {'n_neighbors': 4, 'weights': 'distance'}           0.986111
# 8     {'n_neighbors': 5, 'weights': 'uniform'}           0.930556
# 9    {'n_neighbors': 5, 'weights': 'distance'}           0.986111
# 10    {'n_neighbors': 6, 'weights': 'uniform'}           0.916667
# 11   {'n_neighbors': 6, 'weights': 'distance'}           0.986111
# 12    {'n_neighbors': 7, 'weights': 'uniform'}           0.958333
# 13   {'n_neighbors': 7, 'weights': 'distance'}           1.000000
# 14    {'n_neighbors': 8, 'weights': 'uniform'}           0.944444
# 15   {'n_neighbors': 8, 'weights': 'distance'}           1.000000
# 16    {'n_neighbors': 9, 'weights': 'uniform'}           0.916667
# 17   {'n_neighbors': 9, 'weights': 'distance'}           1.000000
# 18   {'n_neighbors': 10, 'weights': 'uniform'}           0.888889
# 19  {'n_neighbors': 10, 'weights': 'distance'}           1.000000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           0.972222           0.986111
# 1            1.000000           0.972222           0.986111
# 2            0.930556           0.916667           0.930556
# 3            1.000000           0.972222           0.986111
# 4            0.833333           0.902778           0.861111
# 5            1.000000           0.972222           1.000000
# 6            0.805556           0.888889           0.875000
# 7            1.000000           0.972222           1.000000
# 8            0.805556           0.847222           0.916667
# 9            0.986111           0.972222           1.000000
# 10           0.833333           0.888889           0.888889
# 11           1.000000           0.972222           1.000000
# 12           0.875000           0.902778           0.930556
# 13           1.000000           0.972222           1.000000
# 14           0.819444           0.888889           0.916667
# 15           1.000000           0.972222           1.000000
# 16           0.819444           0.875000           0.902778
# 17           1.000000           0.972222           1.000000
# 18           0.791667           0.861111           0.902778
# 19           1.000000           0.972222           1.000000
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            1.000000           0.986111           0.972222
# 1            1.000000           0.986111           0.972222
# 2            0.958333           0.944444           0.902778
# 3            1.000000           0.986111           0.972222
# 4            0.875000           0.916667           0.888889
# 5            1.000000           0.986111           0.972222
# 6            0.888889           0.875000           0.875000
# 7            1.000000           0.986111           0.972222
# 8            0.888889           0.902778           0.888889
# 9            1.000000           0.986111           0.972222
# 10           0.888889           0.916667           0.902778
# 11           1.000000           0.986111           0.972222
# 12           0.902778           0.902778           0.916667
# 13           1.000000           0.986111           0.986111
# 14           0.902778           0.888889           0.930556
# 15           1.000000           0.986111           0.986111
# 16           0.875000           0.875000           0.902778
# 17           1.000000           0.986111           1.000000
# 18           0.875000           0.861111           0.875000
# 19           1.000000           0.986111           1.000000
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.985915           0.957746           0.943662         0.979010
# 1            0.985915           0.957746           0.943662         0.979010
# 2            0.943662           0.901408           0.845070         0.921792
# 3            0.985915           0.957746           0.943662         0.979010
# 4            0.845070           0.845070           0.774648         0.867312
# 5            1.000000           0.971831           0.943662         0.983216
# 6            0.859155           0.816901           0.774648         0.856182
# 7            0.985915           0.971831           0.943662         0.981808
# 8            0.901408           0.802817           0.760563         0.864534
# 9            0.985915           0.957746           0.957746         0.980419
# 10           0.915493           0.802817           0.760563         0.871498
# 11           0.985915           0.957746           0.957746         0.981808
# 12           0.915493           0.873239           0.788732         0.896635
# 13           0.985915           0.957746           0.957746         0.984585
# 14           0.915493           0.845070           0.816901         0.886913
# 15           0.985915           0.957746           0.957746         0.984585
# 16           0.887324           0.830986           0.816901         0.870188
# 17           0.985915           0.957746           0.985915         0.988791
# 18           0.887324           0.845070           0.802817         0.859077
# 19           0.985915           0.957746           0.957746         0.985974
#
#     std_test_score  rank_test_score
# 0         0.016953                9
# 1         0.016953                9
# 2         0.031117               12
# 3         0.016953                9
# 4         0.043574               17
# 5         0.017548                5
# 6         0.040169               20
# 7         0.016689                6
# 8         0.054298               18
# 9         0.014341                8
# 10        0.051363               15
# 11        0.015455                6
# 12        0.042995               13
# 13        0.015970                3
# 14        0.042873               14
# 15        0.015970                3
# 16        0.034057               16
# 17        0.013749                1
# 18        0.034666               19
# 19        0.016632                2
# KNeighborsClassifier(n_neighbors=np.int64(9), weights='distance')
# 0.9887910798122066
